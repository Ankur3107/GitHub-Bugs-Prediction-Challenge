# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/ankur.kumar/Downloads/all_submitted_files.csv', sep='\t')

# %%
data
# Out:
#                                                  File         Submitted On  \
# 0             bert-base-uncased-maxlen320-2epochs.csv  08/10/2020 18:47:03
# 1   bert-base-uncased-maxlen320-3epochs-2LacInput.csv  08/10/2020 19:32:53
# 2   github-bert-base-uncased-maxlen320-2epochs-2la...  09/10/2020 07:20:51
# 3             roberta-base-maxlen320-3epochs-2lac.csv  09/10/2020 08:29:33
# 4      github-roberta-base-maxlen320-2epochs-2lac.csv  09/10/2020 12:18:43
# ..                                                ...                  ...
# 90                             multi_model_svc_v4.csv  18/10/2020 06:04:46
# 91                   multi_model_equal_weights_v5.csv  18/10/2020 06:26:59
# 92               multi_model_optimized_weights_v5.csv  18/10/2020 06:29:46
# 93                             multi_model_svc_v6.csv  18/10/2020 06:56:15
# 94                              multi_model_lr_v7.csv  18/10/2020 06:56:39
#
#                                             Comment  Public Score  \
# 0               bert-base-uncased-maxlen320-2epochs      0.829333
# 1     bert-base-uncased-maxlen320-3epochs-2LacInput      0.835000
# 2   github-bert-base-uncased-maxlen320-2epochs-2lac      0.839222
# 3               roberta-base-maxlen320-3epochs-2lac      0.836444
# 4        github-roberta-base-maxlen320-2epochs-2lac      0.839111
# ..                                              ...           ...
# 90                               multi_model_svc_v4      0.848667
# 91                     multi_model_equal_weights_v5      0.851444
# 92                 multi_model_optimized_weights_v5      0.851222
# 93                               multi_model_svc_v6      0.851444
# 94                                multi_model_lr_v7      0.851889
#
#     Private Score
# 0        0.831167
# 1        0.838233
# 2        0.840633
# 3        0.840033
# 4        0.842267
# ..            ...
# 90       0.853367
# 91       0.855867
# 92       0.855567
# 93       0.855900
# 94       0.856133
#
# [95 rows x 5 columns]

# %%
data.sort_values('Public Score',ascending = False).head(10)
# Out:
#                                 File         Submitted On  \
# 82               ensemble_v9_svm.csv  17/10/2020 11:13:46
# 94             multi_model_lr_v7.csv  18/10/2020 06:56:39
# 61                 ensemble_v8_1.csv  15/10/2020 09:23:56
# 60                 ensemble_v8_1.csv  15/10/2020 09:17:16
# 66         level3ensemble_new_v4.csv  15/10/2020 19:42:36
# 65                 ensemble_v9_1.csv  15/10/2020 19:42:04
# 64                 ensemble_v9_1.csv  15/10/2020 19:24:19
# 93            multi_model_svc_v6.csv  18/10/2020 06:56:15
# 91  multi_model_equal_weights_v5.csv  18/10/2020 06:26:59
# 86             multi_model_lr_v1.csv  17/10/2020 21:43:40
#
#                          Comment  Public Score  Private Score
# 82               ensemble_v9_svm      0.852111       0.854700
# 94             multi_model_lr_v7      0.851889       0.856133
# 61                 ensemble_v8_2      0.851889       0.854533
# 60                 ensemble_v8_1      0.851889       0.854533
# 66         level3ensemble_new_v4      0.851778       0.855300
# 65         level3ensemble_new_v4      0.851556       0.854733
# 64                 ensemble_v9_1      0.851556       0.854733
# 93            multi_model_svc_v6      0.851444       0.855900
# 91  multi_model_equal_weights_v5      0.851444       0.855867
# 86             multi_model_lr_v1      0.851444       0.855533

# %%
data.sort_values('Private Score',ascending = False).head(10)
# Out:
#                                     File         Submitted On  \
# 94                 multi_model_lr_v7.csv  18/10/2020 06:56:39
# 93                multi_model_svc_v6.csv  18/10/2020 06:56:15
# 91      multi_model_equal_weights_v5.csv  18/10/2020 06:26:59
# 92  multi_model_optimized_weights_v5.csv  18/10/2020 06:29:46
# 86                 multi_model_lr_v1.csv  17/10/2020 21:43:40
# 66             level3ensemble_new_v4.csv  15/10/2020 19:42:36
# 68             level3ensemble_new_v6.csv  15/10/2020 19:52:43
# 56             level3ensemble_new_v1.csv  14/10/2020 19:47:30
# 88                multi_model_svc_v2.csv  17/10/2020 21:44:56
# 87                multi_model_svc_v2.csv  17/10/2020 21:44:25
#
#                              Comment  Public Score  Private Score
# 94                 multi_model_lr_v7      0.851889       0.856133
# 93                multi_model_svc_v6      0.851444       0.855900
# 91      multi_model_equal_weights_v5      0.851444       0.855867
# 92  multi_model_optimized_weights_v5      0.851222       0.855567
# 86                 multi_model_lr_v1      0.851444       0.855533
# 66             level3ensemble_new_v4      0.851778       0.855300
# 68             level3ensemble_new_v6      0.851111       0.854867
# 56             level3ensemble_new_v1      0.850889       0.854800
# 88                 multi_model_nn_v3      0.850889       0.854733
# 87                multi_model_svc_v2      0.850889       0.854733

# %%
data['Public Score'].plot()
data['Private Score'].plot()
# Out:
# <AxesSubplot:>
